# %% [markdown]
# # import libraries

# %%
#OS libs
import os
import shutil
import itertools
import pathlib

# %%
#Data handling tools
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix , classification_report

# %%
#Deep learning libs
import tensorflow as tf
from tensorflow import keras
from keras import layers, Model
from keras.models import Sequential, Model
from keras.layers import Conv2D , MaxPooling2D , Flatten , Activation , Dense , Dropout , BatchNormalization, GlobalAveragePooling2D, Multiply, Layer, LSTM, Input, multiply, TimeDistributed, Reshape, Concatenate
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam , Adamax
from keras import regularizers

# %%
#Warningds
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # load data

# %%
train_data_path = 'data\Training'

filepaths =[]
labels = []

folds = os.listdir(train_data_path)

for fold in folds:
    f_path = os.path.join(train_data_path , fold)
    filelists = os.listdir(f_path)
    
    for file in filelists:
        filepaths.append(os.path.join(f_path , file))
        labels.append(fold)
        
#Concat data paths with labels
Fseries = pd.Series(filepaths , name = 'filepaths')
Lseries = pd.Series(labels , name = 'label')
train_df = pd.concat([Fseries , Lseries] , axis = 1)

# %%
train_df
# Out:
#                                    filepaths      label
# 0      data\Training\glioma\Tr-glTr_0000.jpg     glioma
# 1      data\Training\glioma\Tr-glTr_0001.jpg     glioma
# 2      data\Training\glioma\Tr-glTr_0002.jpg     glioma
# 3      data\Training\glioma\Tr-glTr_0003.jpg     glioma
# 4      data\Training\glioma\Tr-glTr_0004.jpg     glioma
# ...                                      ...        ...
# 5195  data\Training\pituitary\Tr-pi_1452.jpg  pituitary
# 5196  data\Training\pituitary\Tr-pi_1453.jpg  pituitary
# 5197  data\Training\pituitary\Tr-pi_1454.jpg  pituitary
# 5198  data\Training\pituitary\Tr-pi_1455.jpg  pituitary
# 5199  data\Training\pituitary\Tr-pi_1456.jpg  pituitary
#
# [5200 rows x 2 columns]

# %%
test_data_path = 'data\Testing'

filepaths =[]
labels = []

folds = os.listdir(test_data_path)

for fold in folds:
    f_path = os.path.join(test_data_path , fold)
    filelists = os.listdir(f_path)
    
    for file in filelists:
        filepaths.append(os.path.join(f_path , file))
        labels.append(fold)
        
#Concat data paths with labels
Fseries = pd.Series(filepaths , name = 'filepaths')
Lseries = pd.Series(labels , name = 'label')
test_df = pd.concat([Fseries , Lseries] , axis = 1)

# %%
test_df
# Out:
#                                   filepaths      label
# 0      data\Testing\glioma\Te-glTr_0000.jpg     glioma
# 1      data\Testing\glioma\Te-glTr_0001.jpg     glioma
# 2      data\Testing\glioma\Te-glTr_0002.jpg     glioma
# 3      data\Testing\glioma\Te-glTr_0003.jpg     glioma
# 4      data\Testing\glioma\Te-glTr_0004.jpg     glioma
# ...                                     ...        ...
# 1195  data\Testing\pituitary\Te-pi_0295.jpg  pituitary
# 1196  data\Testing\pituitary\Te-pi_0296.jpg  pituitary
# 1197  data\Testing\pituitary\Te-pi_0297.jpg  pituitary
# 1198  data\Testing\pituitary\Te-pi_0298.jpg  pituitary
# 1199  data\Testing\pituitary\Te-pi_0299.jpg  pituitary
#
# [1200 rows x 2 columns]

# %% [markdown]
# # Split Test Data into Valid and Test

# %%
valid , test = train_test_split(test_df , train_size = 0.5 , shuffle = True , random_state= 42)

# %%
# Define image size and batch size
img_size = (256, 256)
batch_size = 16

# Create ImageDataGenerator instances for training, validation, and testing
tr_gen = ImageDataGenerator()
ts_gen = ImageDataGenerator()

# Create data generators for training, validation, and testing
train_gen = tr_gen.flow_from_dataframe(train_df, 
                                        x_col='filepaths', 
                                        y_col='label', 
                                        target_size = img_size,
                                        class_mode = 'categorical',
                                        color_mode = 'rgb',
                                        shuffle = True,
                                        batch_size = batch_size)

valid_gen = ts_gen.flow_from_dataframe(valid, 
                                        x_col = 'filepaths', 
                                        y_col=  'label', 
                                        target_size = img_size, 
                                        class_modeb = 'categorical',
                                        color_mode = 'rgb', 
                                        shuffle = True, 
                                        batch_size = batch_size)

test_gen = ts_gen.flow_from_dataframe(test, 
                                        x_col = 'filepaths', 
                                        y_col = 'label', 
                                        target_size = img_size, 
                                        class_mode = 'categorical', 
                                        color_mode = 'rgb', 
                                        shuffle = False, 
                                        batch_size = batch_size)
# Out:
# Found 5200 validated image filenames belonging to 4 classes.
# Found 600 validated image filenames belonging to 4 classes.
# Found 600 validated image filenames belonging to 4 classes.

# %% [markdown]
# # Show sample from train data

# %%
gen_dict = train_gen.class_indices
classes = list(gen_dict.keys())
images , labels = next(train_gen)

plt.figure(figsize= (12,8))

for i in range(16):
    plt.subplot(4,4,i+1)
    image = images[i] / 255
    plt.imshow(image)
    index = np.argmax(labels[i])
    class_name = classes[index]
    plt.title(class_name , color = 'blue' , fontsize= 16)
    plt.axis('off')
plt.show()

# %%
classes
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %% [markdown]
# # Model Structure

# %%
import keras.backend as K
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
    tf.keras.metrics.BinaryAccuracy(name='accuracy'),
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall'),
    tf.keras.metrics.AUC(name='auc'),
    f1_score,
]

# %%
img_shape = (256, 256, 3)
num_class = len(classes)

# %%
from keras.applications.vgg16 import VGG16

base_model = VGG16(input_shape = img_shape, include_top=False, weights='imagenet')

# Set all layers to non-trainable
for layer in base_model.layers:
    layer.trainable = False
# Set the last vgg block to trainable
base_model.layers[-2].trainable = True
base_model.layers[-3].trainable = True
base_model.layers[-4].trainable = True

model = Sequential()
model.add(Input(shape=(256,256,3)))
model.add(base_model)
model.add(Flatten())
model.add(Dropout(0.3))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_class, activation='softmax'))

# %%
model.compile(Adamax(learning_rate = 0.001) , loss = 'categorical_crossentropy', metrics = METRICS)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 8, 8, 512)         14714688
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dropout (Dropout)           (None, 32768)             0
#
#  dense (Dense)               (None, 128)               4194432
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 18909636 (72.13 MB)
# Trainable params: 11274372 (43.01 MB)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________

# %%
Epochs = 50

history = model.fit(x= train_gen , epochs = Epochs , verbose = 1 , validation_data = valid_gen ,
                validation_steps = None , shuffle = False)
# Out:
# Epoch 1/50
# 325/325 [==============================] - 1848s 6s/step - loss: 1.4070 - accuracy: 0.7555 - precision: 0.5470 - recall: 0.1275 - auc: 0.7073 - f1_score: 0.1900 - val_loss: 1.1510 - val_accuracy: 0.7812 - val_precision: 0.6482 - val_recall: 0.2733 - val_auc: 0.7622 - val_f1_score: 0.3804
# Epoch 2/50
# 325/325 [==============================] - 869s 3s/step - loss: 0.9436 - accuracy: 0.8073 - precision: 0.6980 - recall: 0.4040 - auc: 0.8471 - f1_score: 0.5024 - val_loss: 0.8528 - val_accuracy: 0.8117 - val_precision: 0.7284 - val_recall: 0.3933 - val_auc: 0.8789 - val_f1_score: 0.5082
# Epoch 3/50
# 325/325 [==============================] - 885s 3s/step - loss: 0.7267 - accuracy: 0.8572 - precision: 0.7830 - recall: 0.5933 - auc: 0.9113 - f1_score: 0.6698 - val_loss: 0.7903 - val_accuracy: 0.8562 - val_precision: 0.7392 - val_recall: 0.6567 - val_auc: 0.9056 - val_f1_score: 0.6947
# Epoch 4/50
# 325/325 [==============================] - 896s 3s/step - loss: 0.5939 - accuracy: 0.8876 - precision: 0.8259 - recall: 0.6977 - auc: 0.9400 - f1_score: 0.7539 - val_loss: 0.5374 - val_accuracy: 0.8921 - val_precision: 0.8018 - val_recall: 0.7550 - val_auc: 0.9496 - val_f1_score: 0.7779
# Epoch 5/50
# 325/325 [==============================] - 931s 3s/step - loss: 0.4714 - accuracy: 0.9144 - precision: 0.8691 - recall: 0.7740 - auc: 0.9615 - f1_score: 0.8163 - val_loss: 0.5226 - val_accuracy: 0.9042 - val_precision: 0.8212 - val_recall: 0.7883 - val_auc: 0.9545 - val_f1_score: 0.8050
# Epoch 6/50
# 325/325 [==============================] - 956s 3s/step - loss: 0.3977 - accuracy: 0.9298 - precision: 0.8860 - recall: 0.8254 - auc: 0.9718 - f1_score: 0.8534 - val_loss: 0.5677 - val_accuracy: 0.9038 - val_precision: 0.8143 - val_recall: 0.7967 - val_auc: 0.9536 - val_f1_score: 0.8077
# Epoch 7/50
# 325/325 [==============================] - 965s 3s/step - loss: 0.3306 - accuracy: 0.9422 - precision: 0.9024 - recall: 0.8621 - auc: 0.9799 - f1_score: 0.8812 - val_loss: 0.3378 - val_accuracy: 0.9246 - val_precision: 0.8581 - val_recall: 0.8367 - val_auc: 0.9784 - val_f1_score: 0.8443
# Epoch 8/50
# 325/325 [==============================] - 947s 3s/step - loss: 0.2800 - accuracy: 0.9491 - precision: 0.9106 - recall: 0.8831 - auc: 0.9852 - f1_score: 0.8961 - val_loss: 0.3818 - val_accuracy: 0.9350 - val_precision: 0.8788 - val_recall: 0.8583 - val_auc: 0.9730 - val_f1_score: 0.8699
# Epoch 9/50
# 325/325 [==============================] - 945s 3s/step - loss: 0.2589 - accuracy: 0.9538 - precision: 0.9157 - recall: 0.8977 - auc: 0.9867 - f1_score: 0.9063 - val_loss: 0.3013 - val_accuracy: 0.9479 - val_precision: 0.9074 - val_recall: 0.8817 - val_auc: 0.9824 - val_f1_score: 0.8956
# Epoch 10/50
# 325/325 [==============================] - 961s 3s/step - loss: 0.1991 - accuracy: 0.9650 - precision: 0.9347 - recall: 0.9244 - auc: 0.9917 - f1_score: 0.9292 - val_loss: 0.3003 - val_accuracy: 0.9554 - val_precision: 0.9129 - val_recall: 0.9083 - val_auc: 0.9818 - val_f1_score: 0.9085
# Epoch 11/50
# 325/325 [==============================] - 953s 3s/step - loss: 0.1734 - accuracy: 0.9675 - precision: 0.9391 - recall: 0.9306 - auc: 0.9939 - f1_score: 0.9347 - val_loss: 0.2924 - val_accuracy: 0.9554 - val_precision: 0.9143 - val_recall: 0.9067 - val_auc: 0.9842 - val_f1_score: 0.9101
# Epoch 12/50
# 325/325 [==============================] - 915s 3s/step - loss: 0.1510 - accuracy: 0.9709 - precision: 0.9446 - recall: 0.9385 - auc: 0.9953 - f1_score: 0.9415 - val_loss: 0.3853 - val_accuracy: 0.9458 - val_precision: 0.8917 - val_recall: 0.8917 - val_auc: 0.9822 - val_f1_score: 0.8914
# Epoch 13/50
# 325/325 [==============================] - 961s 3s/step - loss: 0.1298 - accuracy: 0.9772 - precision: 0.9562 - recall: 0.9523 - auc: 0.9960 - f1_score: 0.9542 - val_loss: 0.1813 - val_accuracy: 0.9675 - val_precision: 0.9365 - val_recall: 0.9333 - val_auc: 0.9930 - val_f1_score: 0.9358
# Epoch 14/50
# 325/325 [==============================] - 944s 3s/step - loss: 0.1040 - accuracy: 0.9809 - precision: 0.9628 - recall: 0.9606 - auc: 0.9970 - f1_score: 0.9616 - val_loss: 0.2417 - val_accuracy: 0.9608 - val_precision: 0.9231 - val_recall: 0.9200 - val_auc: 0.9873 - val_f1_score: 0.9224
# Epoch 15/50
- val_precision: 0.9500 - val_recall: 0.9500 - val_auc: 0.9878 - val_f1_score: 0.9490
# Epoch 42/50
# 325/325 [==============================] - 967s 3s/step - loss: 0.0113 - accuracy: 0.9987 - precision: 0.9973 - recall: 0.9973 - auc: 0.9996 - f1_score: 0.9973 - val_loss: 0.4134 - val_accuracy: 0.9758 - val_precision: 0.9517 - val_recall: 0.9517 - val_auc: 0.9822 - val_f1_score: 0.9523
# Epoch 43/50
# 325/325 [==============================] - 955s 3s/step - loss: 0.0085 - accuracy: 0.9989 - precision: 0.9979 - recall: 0.9979 - auc: 0.9999 - f1_score: 0.9979 - val_loss: 0.5212 - val_accuracy: 0.9750 - val_precision: 0.9500 - val_recall: 0.9500 - val_auc: 0.9814 - val_f1_score: 0.9507
# Epoch 44/50
# 325/325 [==============================] - 957s 3s/step - loss: 0.0074 - accuracy: 0.9993 - precision: 0.9987 - recall: 0.9987 - auc: 0.9997 - f1_score: 0.9987 - val_loss: 0.5653 - val_accuracy: 0.9792 - val_precision: 0.9583 - val_recall: 0.9583 - val_auc: 0.9818 - val_f1_score: 0.9589
# Epoch 45/50
# 325/325 [==============================] - 947s 3s/step - loss: 0.0203 - accuracy: 0.9981 - precision: 0.9962 - recall: 0.9962 - auc: 0.9995 - f1_score: 0.9962 - val_loss: 1.0766 - val_accuracy: 0.9683 - val_precision: 0.9367 - val_recall: 0.9367 - val_auc: 0.9752 - val_f1_score: 0.9375
# Epoch 46/50
# 325/325 [==============================] - 953s 3s/step - loss: 0.0078 - accuracy: 0.9989 - precision: 0.9981 - recall: 0.9975 - auc: 0.9998 - f1_score: 0.9978 - val_loss: 0.5541 - val_accuracy: 0.9742 - val_precision: 0.9483 - val_recall: 0.9483 - val_auc: 0.9793 - val_f1_score: 0.9490
# Epoch 47/50
# 325/325 [==============================] - 973s 3s/step - loss: 0.0013 - accuracy: 0.9999 - precision: 0.9998 - recall: 0.9998 - auc: 0.9999 - f1_score: 0.9998 - val_loss: 0.5131 - val_accuracy: 0.9792 - val_precision: 0.9583 - val_recall: 0.9583 - val_auc: 0.9848 - val_f1_score: 0.9589
# Epoch 48/50
# 325/325 [==============================] - 1093s 3s/step - loss: 0.0275 - accuracy: 0.9973 - precision: 0.9946 - recall: 0.9944 - auc: 0.9991 - f1_score: 0.9945 - val_loss: 0.4646 - val_accuracy: 0.9708 - val_precision: 0.9417 - val_recall: 0.9417 - val_auc: 0.9808 - val_f1_score: 0.9408
# Epoch 49/50
# 325/325 [==============================] - 1045s 3s/step - loss: 0.0101 - accuracy: 0.9986 - precision: 0.9971 - recall: 0.9971 - auc: 0.9997 - f1_score: 0.9971 - val_loss: 0.6220 - val_accuracy: 0.9758 - val_precision: 0.9517 - val_recall: 0.9517 - val_auc: 0.9779 - val_f1_score: 0.9507
# Epoch 50/50
# 325/325 [==============================] - 994s 3s/step - loss: 0.0204 - accuracy: 0.9980 - precision: 0.9960 - recall: 0.9960 - auc: 0.9992 - f1_score: 0.9960 - val_loss: 0.4654 - val_accuracy: 0.9804 - val_precision: 0.9616 - val_recall: 0.9600 - val_auc: 0.9790 - val_f1_score: 0.9612

# %%
model.save("complete_model.h5")
model.save_weights("model_weights.h5")

# %% [markdown]
# # Performace

# %%
train_acc = history.history['accuracy']
train_loss = history.history['loss']

val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]

index_acc = np.argmax(val_acc)
val_highest = val_acc[index_acc]

Epochs = [i+1 for i in range(len(train_acc))]

loss_label = f'Best epochs = {str(index_loss +1)}'
acc_label = f'Best epochs = {str(index_acc + 1)}'

#Training history

plt.figure(figsize= (12,6))
plt.style.use('fivethirtyeight')

plt.subplot(1,2,1)
plt.plot(Epochs , train_loss, label = 'Training Loss')
plt.plot(Epochs , val_loss, label = 'Validation Loss')
plt.scatter(index_loss + 1 , val_lowest , s = 100, c = 'blue', label = loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1,2,2)
plt.plot(Epochs , train_acc, label = 'Training Accuracy')
plt.plot(Epochs , val_acc, label = 'Validation Accuracy')
plt.scatter(index_acc + 1 , val_highest , s = 100 , c = 'blue', label = acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout
plt.show();

# %% [markdown]
# # Evaluation

# %%
test_loss = model.evaluate(test_gen)
print("Test Loss:", test_loss)
# Out:
# 38/38 [==============================] - 75s 2s/step - loss: 0.8049 - accuracy: 0.9712 - precision: 0.9432 - recall: 0.9417 - auc: 0.9771 - f1_score: 0.9432
# Test Loss: [0.8049443364143372, 0.9712499976158142, 0.9432387351989746, 0.9416666626930237, 0.9770726561546326, 0.9432300925254822]

# %%
train_score = model.evaluate(train_gen , steps =16 , verbose = 1)
valid_score = model.evaluate(valid_gen , steps = 16 , verbose = 1)
test_score = model.evaluate(test_gen , steps = 16 , verbose = 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Validation Loss: ", valid_score[0])
print("Validation Accuracy: ", valid_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 16/16 [==============================] - 31s 2s/step - loss: 0.0013 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000
# 16/16 [==============================] - 34s 2s/step - loss: 0.4062 - accuracy: 0.9844 - precision: 0.9688 - recall: 0.9688 - auc: 0.9838 - f1_score: 0.9688
# 16/16 [==============================] - 34s 2s/step - loss: 0.7140 - accuracy: 0.9717 - precision: 0.9451 - recall: 0.9414 - auc: 0.9796 - f1_score: 0.9433
# Train Loss:  0.0013080992503091693
# Train Accuracy:  1.0
# --------------------
# Validation Loss:  0.40621867775917053
# Validation Accuracy:  0.984375
# --------------------
# Test Loss:  0.7140238285064697
# Test Accuracy:  0.9716796875

# %% [markdown]
# # Predection

# %%
preds = model.predict_generator(test_gen)

y_pred = np.argmax(preds , axis = 1)

# %%
g_dict = test_gen.class_indices
classes = list(g_dict.keys())

# Confusion matrix
cm = confusion_matrix(test_gen.classes, y_pred)

plt.figure(figsize= (12, 8))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %%
#Classification Report
print(classification_report(test_gen.classes, y_pred , target_names= classes ))
# Out:
#               precision    recall  f1-score   support
#
#       glioma       0.94      0.95      0.94       150
#   meningioma       0.95      0.85      0.89       169
#      notumor       0.90      1.00      0.95       143
#    pituitary       0.99      0.99      0.99       138
#
#     accuracy                           0.94       600
#    macro avg       0.94      0.95      0.94       600
# weighted avg       0.94      0.94      0.94       600

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)

plt.figure(figsize=(6, 4))

plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('Training and Validation Loss', fontsize=12)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Loss', fontsize=10)
plt.legend(fontsize=10)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.grid(False)

plt.tight_layout()
plt.show()

# %%
with tf.keras.utils.custom_object_scope({'f1_score': f1_score}):
    loaded_model = tf.keras.models.load_model("complete_model.h5")
    loaded_model.load_weights("model_weights.h5")
    
def predict(img_path):
    label = list(gen_dict.keys())
    plt.figure(figsize=(6, 8))  # Adjust figure size to accommodate the image and predictions
    
    img = Image.open(img_path)
    resized_img = img.resize((256, 256))
    img = np.asarray(resized_img)
    img = np.expand_dims(img, axis=0)
    img = img / 255
    predictions = loaded_model.predict(img)
    probs = list(predictions[0])
    labels = label
    
    # Find the label with the maximum probability
    max_prob_index = np.argmax(probs)
    max_label = labels[max_prob_index]
    max_prob = probs[max_prob_index]
    
    # Plot image
    plt.imshow(resized_img)
    plt.axis('off')  # Turn off axis
    
    # Print label with maximum probability
    plt.text(0.5, -0.1, f'{max_label}: {max_prob:.2f}', color='blue', fontsize = 16, ha='center', va='center', transform=plt.gca().transAxes)
    
    # Return label and probability
    return max_label, max_prob

# %%
from detection import detect_tumor

# %%
detect_tumor("p.jpg")
max_label, max_prob = predict("p.jpg")
# print("Label with the highest probability:", max_label)
# print("Probability:", max_prob)
# Out:
# 1/1 [==============================] - 1s 571ms/step
